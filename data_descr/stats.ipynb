# %%
import pandas as pd
import numpy as np

dims = [2, 3, 4, 5]

dim = 4
df = pd.read_csv('../solver/stats_{}.csv'.format(dim))
df
# Out:
#       seconds  level  variables   used  original  conflicts  learned  limit  \
# 0         0.0   16.3        667   99.1       149        719      702   1464
# 1         0.0   14.0        644   96.6       151        470      442   1331
# 2         0.0    0.0          0  100.0         0         21        0      0
# 3         0.1   22.2        705   99.0       152       2059     1999   2142
# 4         0.0    0.0          0  100.0         0          6        0      0
# 5         0.0    0.0          0  100.0         0         39        0      0
# 6         0.1   18.1        701   99.5       152       1993     1922   2142
# 7         0.0   14.1        700   99.2       153        376      374   1331
# 8         0.0   21.7        755   99.4       158       1295     1282   1771
# 9         0.1   18.4        644   99.8       146       2329     2236   2356
# 10        0.0   22.0        661   99.6       150       1227     1184   1771
# ...
